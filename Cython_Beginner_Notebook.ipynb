# %% [markdown]
# # **Cython for Absolute Beginners — Step-by-Step Notebook**
#
# This notebook teaches Cython using **very simple examples**.
# No C knowledge required. If you can write Python, you can follow this notebook.

# %% [markdown]
# ## 1. Load Cython extension
# If this fails, run:
# ```
# pip install cython
# ```

# %%
# %load_ext cython

# %% [markdown]
# ## 2. Your first Cython function
# Looks exactly like Python.

# %%
# %%cython
#
# def hello(name):
#     print("Hello", name)
# Out:
# Content of stdout:
# _cython_magic_4b8440d3a6b35fe008efe78c45f163d9e25c589a.c
#    Creating library C:\Users\taufi\.ipython\cython\Users\taufi\.ipython\cython\_cython_magic_4b8440d3a6b35fe008efe78c45f163d9e25c589a.cp310-win_amd64.lib and object C:\Users\taufi\.ipython\cython\Users\taufi\.ipython\cython\_cython_magic_4b8440d3a6b35fe008efe78c45f163d9e25c589a.cp310-win_amd64.exp
# Generating code
# Finished generating code

# %%
hello("Data Science Students!")
# Out:
# Hello Data Science Students!

# %% [markdown]
# ## 3. A slow Python loop
# We start with normal Python.

# %%
def py_square(numbers):
    result = []
    for n in numbers:
        result.append(n*n)
    return result

nums = list(range(200000))
# %timeit py_square(nums)
# Out:
# 15.3 ms ± 740 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## 4. The same code in Cython (no types yet)
# Even without types, Cython will make it faster.

# %%
# %%cython
#
# def cy_square(numbers):
#     result = []
#     for n in numbers:
#         result.append(n*n)
#     return result
# Out:
# Content of stdout:
# _cython_magic_c7727984e4efa7167b729b88e176120771cd6345.c
#    Creating library C:\Users\taufi\.ipython\cython\Users\taufi\.ipython\cython\_cython_magic_c7727984e4efa7167b729b88e176120771cd6345.cp310-win_amd64.lib and object C:\Users\taufi\.ipython\cython\Users\taufi\.ipython\cython\_cython_magic_c7727984e4efa7167b729b88e176120771cd6345.cp310-win_amd64.exp
# Generating code
# Finished generating code

# %%
# %timeit cy_square(nums)
# Out:
# 5.93 ms ± 196 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## 5. Adding just **one** typed variable
# This makes it even faster.

# %%
# %%cython
#
# def cy_square_fast(numbers):
#     cdef int n
#     result = []
#     for n in numbers:
#         result.append(n*n)
#     return result
# Out:
# Content of stdout:
# _cython_magic_491e81fd0fd1cb921ad1f86f22948c7535392400.c
#    Creating library C:\Users\taufi\.ipython\cython\Users\taufi\.ipython\cython\_cython_magic_491e81fd0fd1cb921ad1f86f22948c7535392400.cp310-win_amd64.lib and object C:\Users\taufi\.ipython\cython\Users\taufi\.ipython\cython\_cython_magic_491e81fd0fd1cb921ad1f86f22948c7535392400.cp310-win_amd64.exp
# Generating code
# Finished generating code

# %%
# %timeit cy_square_fast(nums)
# Out:
# 4.89 ms ± 110 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## 6. Simple NumPy example (no advanced features)
# Cython improves loops even with NumPy.

# %%
import numpy as np

def py_add_one(arr):
    out = np.zeros_like(arr)
    for i in range(len(arr)):
        out[i] = arr[i] + 1
    return out

arr = np.arange(300000)
# %timeit py_add_one(arr)
# Out:
# 40.8 ms ± 2.01 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%cython
# import numpy as np
#
# def cy_add_one(arr):
#     out = np.zeros_like(arr)
#     for i in range(len(arr)):
#         out[i] = arr[i] + 1
#     return out
# Out:
# Content of stdout:
# _cython_magic_bb12f1185c86e8a97471f896d1a24214a980257e.c
#    Creating library C:\Users\taufi\.ipython\cython\Users\taufi\.ipython\cython\_cython_magic_bb12f1185c86e8a97471f896d1a24214a980257e.cp310-win_amd64.lib and object C:\Users\taufi\.ipython\cython\Users\taufi\.ipython\cython\_cython_magic_bb12f1185c86e8a97471f896d1a24214a980257e.cp310-win_amd64.exp
# Generating code
# Finished generating code

# %%
# %timeit cy_add_one(arr)
# Out:
# 42.1 ms ± 3.21 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ## 7. What did we learn?
# - You can write Cython **just like Python**.
# - Even without types, it can run faster.
# - Adding only one typed variable gives a noticeable speed boost.
# - You don’t need to learn C to start using Cython.
#
# Next steps (not included in beginner notebook):
# - typing arrays
# - using memoryviews
# - compiling `.pyx` files
# - releasing the GIL
#
# You can learn these later once you're comfortable.
